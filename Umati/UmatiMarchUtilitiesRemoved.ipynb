# %% [markdown]
# # Filtering Facebook Comments by Iterative Training

# %% [markdown]
# ## Import All necessary packages (and more!!)

# %%
import sys
import os
import pandas as pd
print pd.version.version
import numpy as np
from datetime import datetime
import codecs



import sqlite3
import psycopg2
import pandas.io.sql as psql

#Magic way to import matplotlib on server with no X-server
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.cross_validation import StratifiedKFold
import time
import pickle
import os

import mlutilities
reload(mlutilities)
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth',1000)
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /usr/local/lib/python2.7/dist-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# 0.13.1

# %% [markdown]
# ## Metric Report generator for k-fold results of a classifier

# %% [markdown]
# ## Import Data and Parse to Correct Types and Filter To Correct Range

# %%
#This only works if you've opened an ssh tunnel from the Azure server to the ihub server via ssh terminal
#With form local Azure server port 9003 to localhost:5432 on ihub server
import psycopg2
# con = psycopg2.connect("dbname='UmatiTestCollect' user='patrick' password='dlabroot' host='localhost' port=9003")
con = psycopg2.connect("dbname='UmatiTestCollect' user='patrick' password='dlabroot' host='41.242.2.145' port=5432")
cur = con.cursor()

# %%
#Import and merge Data
#Read in autocollected posts
df_comments = psql.read_frame('SELECT * FROM fb_comments', con)
df_posts = psql.read_frame('SELECT * FROM fb_posts', con)
df_pages = psql.read_frame('SELECT * FROM scrape_pages', con)
con.close()

# %%
# print df_comments.comment_id.apply(len).value_counts()
# df_comments[df_comments.comment_id.apply(len) == 25][['comment_id','message']].head()

# %%
counts = df_comments.groupby('comment_id').size()
df2 = pd.DataFrame(counts, columns = ['size'])
df2 = df2[df2.size>1]

# %%
df_comments.info()
#df_comments['created_time'].iloc[500000]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 848756 entries, 0 to 848755
# Data columns (total 10 columns):
# id                848756 non-null int64
# fb_post_id        848756 non-null int64
# comment_id        848756 non-null object
# from_user_id      848756 non-null object
# created_time      848756 non-null datetime64[ns]
# from_user_name    848756 non-null object
# message           848756 non-null object
# created_at        848756 non-null datetime64[ns]
# updated_at        848756 non-null datetime64[ns]
# parent_id         848756 non-null object
# dtypes: datetime64[ns](3), int64(2), object(5)

# %%
#Merge page and post info
df_all = pd.merge(df_posts,df_pages, on ='fb_page_id', how = 'left', suffixes = ['_posts','_pages'])
#Merge comment info
df_all = pd.merge(df_comments,df_all, left_on ='fb_post_id', right_on='id_posts', how='left',suffixes=['_comments',''])
df_all['created_time_comments'].head()
#df_all[['created_time_comments']] = df_all[['created_time_comments']].applymap( pdata)
df_all.sort(columns = ['created_time_comments'], inplace=True)
df_all = df_all.set_index('created_time_comments',drop=False) #set as index to subset on

# %%
#Filter to march
df_all_march = df_all['2013-03'] #Subset to march
df_all_march = df_all_march.set_index('comment_id',drop=False)
df_all_march.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441940 entries, 418072774951847_2469204 to 144115289102878_148080
# Data columns (total 33 columns):
# id                           441940 non-null int64
# fb_post_id_comments          441940 non-null int64
# comment_id                   441940 non-null object
# from_user_id                 441940 non-null object
# created_time_comments        441940 non-null datetime64[ns]
# from_user_name               441940 non-null object
# message_comments             441940 non-null object
# created_at                   441940 non-null datetime64[ns]
# updated_at                   441940 non-null datetime64[ns]
# parent_id                    441940 non-null object
# id_posts                     441940 non-null int64
# fb_post_id                   441940 non-null object
# message                      441940 non-null object
# fb_page_id                   441940 non-null object
# created_time                 441940 non-null datetime64[ns]
# ...

# %%
counts = df_all_march.groupby('comment_id').size()
df2 = pd.DataFrame(counts, columns = ['size'])
df2 = df2[df2.size>1]
print df2.shape

dub_label = df_all_march.index.get_duplicates()[0]

# df_all_march.loc[dub_label]
# Out:
# (69, 1)

# %% [markdown]
# ## Import Labels for Data; Sample Data;Ouput for Labelling; Import For Classification

# %% [markdown]
# ### Sample Non-Labelled Data

# %%
sample_index = sample_proportions(labels, df_all_march, sample_size=5000, proportion_weighted=0.8, block_size = 10, top_N=10)
len(sample_index)

# %% [markdown]
# ### Output to HTML file for Annotation

# %%
#Output for annotation
import codecs
thesample = df_all_march.loc[sample_index]
thesample_output = thesample[['comment_id','page_url','message_comments','message']]
with codecs.open('../Data/Annotations1.html','w',encoding='UTF-8') as fout:
    fout.write(thesample_output.to_html())

#from pandas import ExcelWriter
#writer = ExcelWriter('../Data/Annotation1.xlsx')
#thesample = df_all_march.loc[sample_index]
#thesample_output = thesample[['comment_id','page_url','message_comments','message']]
#thesample_output.to_excel(writer, "Sheet1")
#writer.save()

# %% [markdown]
# ### Read in Latest Labels and output to All_Labels table

# %%
#Import all iterations
df_all_labels = pd.read_csv('../Data/UmatiLabels/AllLabelsTable.csv')
df_all_labels = df_all_labels.set_index('comment_id',drop=False)
# df_previouslabels[df_previouslabels.label==True].info()
# df_all_labels = df_all_labels[df_all_labels.iteration!=5]
df_all_labels.drop_duplicates('comment_id',inplace=True)
df_all_labels.info()

# df_all_labels.loc[df_all_labels.index.get_duplicates()][['iteration','label']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11172 entries, 100163516839922_201 to 631934743498720_111026178
# Data columns (total 4 columns):
# comment_id     11172 non-null object
# label          11172 non-null bool
# iteration      11172 non-null int64
# description    11172 non-null object
# dtypes: bool(1), int64(1), object(2)

# %%
###REMEMBER TO CHANGE THE DESCRIPTION###
#Only execute if these labels haven't been read
#Import new labels
#Import newest interation
df_thislabels = pd.read_csv('../Data/UmatiLabels/Labelled/SixthIteration/labels_trues_6thiteration.csv')
df_thislabels.head()
df_thislabels = df_thislabels.dropna(axis=0)
df_thislabels.columns = ['comment_id','label']
df_thislabels['iteration'] = df_all_labels['iteration'].max() + 1


# print df_thislabels.head()
# print df_thislabels['iteration'].value_counts()
print df_thislabels['label'].value_counts()

#Filter misspelling
df_thislabels = df_thislabels[df_thislabels['label']!='T/F']

#Get true and falses independent of label 'T,tt,t' etc
false_filter = df_thislabels['label'].str.contains('[Ff]')
true_filter = df_thislabels['label'].str.contains('[Tt]')


#Relabel to True/False boolean
df_thislabels['label'][false_filter] = False
df_thislabels['label'][true_filter] = True
df_thislabels['label'].value_counts()

#description
df_thislabels['description'] = 'Sixth iteration labelled by Faith'
df_thislabels.head()

# print df_thislabels.head()
# print df_thislabels['iteration'].value_counts()
print df_thislabels['label'].value_counts()

df_thislabels = df_thislabels.set_index('comment_id',drop=False)
df_thislabels.info()
df_thislabels.index.get_duplicates()
# Out:
# F    1654
# T     347
# dtype: int64
# False    1654
# True      347
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 2001 entries, 10151143456029058_24352110 to 631934743498720_111026178
# Data columns (total 4 columns):
# comment_id     2001 non-null object
# label          2001 non-null object
# iteration      2001 non-null int64
# description    2001 non-null object
# dtypes: int64(1), object(3)
# ['10151150233789058_24380520']

# %%
#Concat to existing labels
df_all_labels = pd.concat([df_all_labels,df_thislabels])
print df_all_labels.info()
df_all_labels['label'].value_counts()
df_all_labels['iteration'].value_counts()
df_all_labels['description'].value_counts()
df_all_labels.index.get_duplicates()

# thislabels['iteration'].value_counts()/thislabels[thislabels['label']==True]['iteration'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13173 entries, 100163516839922_201 to 631934743498720_111026178
# Data columns (total 4 columns):
# comment_id     13173 non-null object
# label          13173 non-null object
# iteration      13173 non-null int64
# description    13173 non-null object
# dtypes: int64(1), object(3)None
# ['10151143456029058_24352110',
#  '10151144675644058_24360217',
#  '10151144891459058_24361706',
#  '10151144891459058_24361955',
#  '10151145952254058_24367418',
#  '10151146253204058_24370334',
#  '10151150068484058_24376911',
#  '10151150223229058_24378361',
#  '10151150233789058_24380520',
#  '10151151566729058_24390011',
#  '10151151648164058_24389278',
#  '10151151755214058_24391875',
#  '10151151779949058_24390883',
#  '10151152016134058_24393297',
#  '10151153050919058_24401205',
#  '10151153051699058_24407988',
#  '10151153177789058_24405336',
#  '10151153279979058_24404493',
#  '10151153312924058_24406377',
#  '10151153364804058_24406841',
# ...

# %%
#Write labels to output
#Includes labelled for first iteration of training
#thislabels = thislabels [['comment_id','label','iteration','description']]
df_all_labels = df_all_labels.set_index('comment_id',drop=False)
df_all_labels.to_csv('../Data/UmatiLabels/AllLabelsTable.csv',index=False)
df_all_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11172 entries, 100163516839922_201 to 631934743498720_111026178
# Data columns (total 4 columns):
# comment_id     11172 non-null object
# label          11172 non-null bool
# iteration      11172 non-null int64
# description    11172 non-null object
# dtypes: bool(1), int64(1), object(2)

# %%
df_all_labels.description.value_counts()
# Out:
# Fifth iteration labelled by Faith                          2999
# first iteration labelled by group                          2351
# fourth iteration labelled by Faith                         2141
# second iteration labelled by Faith                         2079
# first iteration labelled by faith                          1470
# Comments from original data found in autocollected data     132
# dtype: int64

# %%
df_all_labels.loc[df_all_labels.iteration==6,'description']#= "Sixth iteration labelled by Faith"
# Out:
# comment_id
# 10151143456029058_24352110    Sixth iteration labelled by Faith
# 10151144675644058_24360217    Sixth iteration labelled by Faith
# 10151144891459058_24361706    Sixth iteration labelled by Faith
# 10151144891459058_24361955    Sixth iteration labelled by Faith
# 10151145952254058_24367418    Sixth iteration labelled by Faith
# 10151146253204058_24370334    Sixth iteration labelled by Faith
# 10151150068484058_24376911    Sixth iteration labelled by Faith
# 10151150223229058_24378361    Sixth iteration labelled by Faith
# 10151150233789058_24380520    Sixth iteration labelled by Faith
# 10151150233789058_24380520    Sixth iteration labelled by Faith
# 10151151566729058_24390011    Sixth iteration labelled by Faith
# 10151151648164058_24389278    Sixth iteration labelled by Faith
# 10151151755214058_24391875    Sixth iteration labelled by Faith
# 10151151779949058_24390883    Sixth iteration labelled by Faith
# ...

# %%
df_ittf = pd.crosstab(df_all_labels['label'], df_all_labels['iteration'], margins=True)
df_ittf
# Out:
# iteration    0     1     2     3     4    5     6    All
# label
# False        0  1452  2097  1989  2102  601  1653   9894
# True       132    18   254    90    39  398   347   1278
# All        132  1470  2351  2079  2141  999  2000  11172
#
# [3 rows x 8 columns]

# %%
df_ittf/df_ittf.sum(axis=0)
# Out:
# iteration    0         1        2         3         4         5        6       All
# label
# False      0.0  0.493878  0.44598  0.478355  0.490892  0.300801  0.41325  0.442803
# True       0.5  0.006122  0.05402  0.021645  0.009108  0.199199  0.08675  0.057197
# All        0.5  0.500000  0.50000  0.500000  0.500000  0.500000  0.50000  0.500000
#
# [3 rows x 8 columns]

# %% [markdown]
# ## Classifier: Train; Evaluate; Predict

# %% [markdown]
# ### Get Data For Classification

# %%
df_all_labels.drop_duplicates(cols='comment_id').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11172 entries, 100163516839922_201 to 631934743498720_111026178
# Data columns (total 4 columns):
# comment_id     11172 non-null object
# label          11172 non-null bool
# iteration      11172 non-null int64
# description    11172 non-null object
# dtypes: bool(1), int64(1), object(2)

# %%
#Get features
# filter_lbls = df_all_labels.iteration.isin([ 0,1,2, 3 ,4 ,5 , 6])
filter_lbls = df_all_labels.iteration.isin([ 0,1,2, 3 ,4 ,5, 6])
labels_ids = pd.Index(df_all_labels[filter_lbls]['comment_id'])
# labels_ids = pd.Index(df_all_labels['comment_id'])
features = df_all_march[['page_url','message','message_comments','from_user_name']].loc[labels_ids]
features.dropna(axis=0) #drop na matches on comment is
features = features[features['message_comments'].apply(type) != float] #Drop label parsed as float
label_ids = features.index

features.info()

# df_all_labels.loc[label_ids]['iteration'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11169 entries, 100163516839922_201 to 631934743498720_111026178
# Data columns (total 4 columns):
# page_url            11169 non-null object
# message             11169 non-null object
# message_comments    11169 non-null object
# from_user_name      11169 non-null object
# dtypes: object(4)

# %%
df_target = df_all_labels.set_index('comment_id',drop=False)
#faith_filter = ~thislabels['description'].str.contains('aith')
#faith_filter
#faith_index = thislabels[faith_filter].index
#features = features.loc[faith_index]
df_target = df_target.loc[label_ids]
df_target.shape
# Out:
# (11169, 4)

# %% [markdown]
# ### Create Target/Labels and Vector Features for Classification

# %%
#Create target/labels
target = df_target['label'].values
#target = thislabels['label'][faith_filter].values
target = np.array(list(target))
target.shape
target
# Out:
# array([False, False, False, ..., False, False, False], dtype=bool)

# %%
#Create features
#Clean text
text_comments2 = features['message_comments']
text_comments2 = text_comments2.str.replace('\r|\n', ' ')
# text_comments2[text_comments2.str.contains( '\n')]

has_poli = text_comments2.str.contains( '[Rr][Aa][Oo]|[Rr]aila|[Uu]huru|[Rr]uto|[Uh]uruto|[\.\s][Cc]ord(ed)*|[Jj]ubile+')
#print "has poli \n", has_poli.value_counts()
has_tribal = text_comments2.str.contains( '[Ll][Uu][Oo]|[Kk][Ii][Kk]([Uu][Yy][Uu])|[Kk][Ii][Uu[Kk]|[Kk]alenj|[Tribe]')
# print "has tribal \n", has_tribal.value_counts()
has_exclamation = text_comments2.str.contains( '\!')
# print "has exclamation \n", has_exclamation.value_counts()
has_danger_word = text_comments2.str.lower().str.contains( 'thief|mwezi|greed|hate|thiev|sham|jigg|devil|bastard|fuck|penis|rig')
# print "has danger \n", has_danger_word.value_counts()
pd.DataFrame(text_comments2[has_danger_word])

#Binary features
df_binary_features = pd.DataFrame(has_poli)
df_binary_features.columns = ['HAS_POLI']
df_binary_features['HAS_TRIBAL']= has_tribal
df_binary_features['HAS_EXCL']= has_exclamation
df_binary_features['HAS_DANGERW']= has_danger_word
df_binary_features.shape
#df_binary_features = pd.DataFrame([has_poli,has_tribal,has_exclamation,has_danger_word],columns=['HAS_POLI','HAS_TRIBAL','HAS_EXCL', 'HAS_DANGERW'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11169 entries, 100163516839922_201 to 631934743498720_111026178
# Data columns (total 1 columns):
# HAS_POLI    11169 non-null bool
# dtypes: bool(1)None
# (11169, 2)
# (11169, 4)

# %%
#Create features

#Input variables
UseTfidf = False #Set to false to use count vect
Tfidf_max_df = 0.2
ngram_range = (1,2)
stop_words = 'english'

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

###Feature Comments Vecotoriser
#This extract text at numpy array
text_comments = features['message_comments']
text_comments = text_comments2.str.replace('\r|\n', ' ')

if UseTfidf:
    vectoriser_comments = TfidfVectorizer(stop_words='english',
					strip_accents='unicode',                    
					ngram_range = ngram_range,
                     max_df = Tfidf_max_df
                    )
else:
    vectoriser_comments = CountVectorizer(stop_words='english',
 					strip_accents='unicode',
 					ngram_range = ngram_range)

t = time.time()
features_comments = vectoriser_comments.fit_transform(text_comments) 
print "training comments to word vector took", time.time()-t, "seconds"
print "features comments dimension ", features_comments.shape
#Change from sparse matrix to dense matrix
#vect_train = features_msg_training.todense() #BIG memory usage 2GB, see how to use the sparse for training

####Vectorise post features
text_posts = features['message']

if UseTfidf:
    vectoriser_posts = TfidfVectorizer(stop_words='english',
					strip_accents='unicode',                    
					ngram_range = ngram_range,
                     max_df = Tfidf_max_df
                    )
else:
    vectoriser_posts = CountVectorizer(stop_words='english',
 					strip_accents='unicode',
 					ngram_range = ngram_range)

t = time.time()
features_posts = vectoriser_posts.fit_transform(text_posts) 
print "training post vectoriser to word vector took", time.time()-t, "seconds"
print "features comments dimension ", features_posts.shape

#Categorical features - Binariser
#Another approach: http://fastml.com/converting-categorical-data-into-numbers-with-pandas-and-scikit-learn/
features_page = features['page_url']
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
pages_bn = lb.fit_transform(list(features_page.values))
lb.classes_
#Convert to sparse matrix to combine with other features
import scipy.sparse as sp #sparse matrix
spages = sp.csc_matrix(pages_bn)
print "Label binarising done"
print "Label dimensions = ", spages.shape


#Add binary values
sbin_vals = sp.csc_matrix(df_binary_features.values)
print "Binary values sparsed"
print "Binary val dimensions = ", sbin_vals.shape

#Combining features
# features_all = sp.hstack([features_posts,features_comments,sbin_vals])
# features_all = sp.hstack([features_posts,features_comments,spages])
# features_all = sp.hstack([features_posts,features_comments])
features_all = features_comments
features_all = sp.csc.csc_matrix(features_all)
print "features_all shape = ", features_all.shape
# Out:
# training comments to word vector took 1.54756212234 seconds
# features comments dimension  (11169, 99384)
# training post vectoriser to word vector took
#  2.04233980179 seconds
# features comments dimension  (11169, 41817)
# Label binarising done
# Label dimensions =  (11169, 23)
# Binary values sparsed
# Binary val dimensions =  (11169, 4)
# features_all shape =  (11169, 99384)

# %%
#Make table of features_labels, index_full, feature_type
df_comments_labels = pd.DataFrame(vectoriser_training.get_feature_names())
df_comments_labels['feature_type']='comments_message'
df_posts_labels = pd.DataFrame(vectoriser_posts.get_feature_names())
df_posts_labels['feature_type']='posts_message'
df_page_labels = pd.DataFrame(lb.classes_)
df_page_labels['feature_type'] = 'page_url'

#Make sure we concatenate in same order as hstacked above 
#### This has to match what we use a X in training below
# df_feature_index_mapping = pd.concat([df_posts_labels, df_comments_labels,df_page_labels])
# df_feature_index_mapping = pd.concat([df_posts_labels, df_comments_labels])
df_feature_index_mapping = df_comments_labels
df_feature_index_mapping.index = range(0,df_feature_index_mapping.shape[0])
print "feature_index_mapping done"
#df_feature_index_mapping.info()
# Out:
# feature_index_mapping done

# %%
feature_index = np.where(features_comments[0,:].todense() > 0)
feature_index = np.array(feature_index[1])[0]
feature_names = vectoriser_training.get_feature_names()
print np.array(feature_names)[[feature_index]]


vectoriser_training.inverse_transform(features_comments[0,:])
# Out:
# [u'ataenda' u'ataenda kuuliza' u'big' u'big bro' u'bro' u'bro zile'
#  u'kabisa' u'kuuliza' u'kuuliza big' u'malenge' u'malenge kabisa'
#  u'mariddle' u'mariddle zake' u'zake' u'zake malenge' u'zile'
#  u'zile mariddle']
# [array([u'ataenda', u'ataenda kuuliza', u'big', u'big bro', u'bro',
#        u'bro zile', u'kabisa', u'kuuliza', u'kuuliza big', u'malenge',
#        u'malenge kabisa', u'mariddle', u'mariddle zake', u'zake',
#        u'zake malenge', u'zile', u'zile mariddle'],
#       dtype='<U68')]

# %% [markdown]
# ### Run Cross Validation on Labelled Data

# %% [markdown]
# ### Do Feature Selection and Run Classifier with Reduced Features

# %%
reload(mlutilities)
#Feature selection
from sklearn.feature_selection import SelectKBest, SelectPercentile, chi2
from sklearn.svm import LinearSVC
from sklearn.feature_selection import RFE


from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import ProbabilisticPCA, SparsePCA, MiniBatchSparsePCA, TruncatedSVD
from sklearn.neural_network import BernoulliRBM

X= features_all
# X = features_comments
# X= df_binary_features.values
y = target
# fs = SelectKBest(score_func=chi2,k=5000)X.shape[1])
# fs = RFE(svc,n_features_to_select=3000)
# fs = BernoulliRBM()n_components = 128,verbose=True)
fs = TruncatedSVD(n_components=1000)
X_red = fs.fit_transform(X,y)
# X_red = X

#This will blow memory with a lot of features
# X_red = X_red.todense()
# Out:
# Time taken = 374.862486124 seconds
# {'recall': array([ 0.8,  0.2]), 'f1': array([ 0.75147198,  0.04098026]), 'auc': 20.399999999999999, 'precision': array([ 0.70849474,  0.02282901]), 'accuracy': 0.73132374223069341}
# [[7910 1970]
#  [1020  250]]

# %%
clf_eval = SGDClassifier(alpha=0.000001, n_iter=200, penalty='l1',n_jobs=4,shuffle=True)#,loss='log')
# clf_eval = KNeighborsClassifier(n_neighbors=6,weights='distance')
# clf_eval = MultinomialNB(alpha=0.1)
# clf_eval = AdaBoostClassifier()
#clf_eval = RandomForestClassifier(n_estimators=10,n_jobs=-1)

clf_eval
X_red.shape
n_folds=10
t0= time.time()
scores, cm, labelandpred = mlutilities.kfold_report(n_folds,clf_eval,X_red,y, index=features.index)
print "Time taken = {} seconds".format(time.time()-t0)
print scores
print cm
# Out:
# Time taken = 324.379539013 seconds
# {'recall': array([ 0.90345671,  0.39090182]), 'f1': array([ 0.9115039 ,  0.36207693]), 'auc': 47.049999999999997, 'precision': array([ 0.92017398,  0.34408115]), 'accuracy': 0.84483672022153544}
# [[8930  950]
#  [ 770  490]]

# %%
#Simple Learning curve
import math
import random

rand_index = list(range(0,len(y)))
random.shuffle(rand_index)


lc_data = {'X':X_red[rand_index,:], 'y':y[rand_index]}
clf = clf_eval
num_points = 20
n_folds = 3


sample_sizes = np.linspace(0,len(y), num_points,endpoint=True)
sample_sizes = map(math.floor,sample_sizes)
sample_sizes

sample_ranges = [ (0, ep) for ep in sample_sizes]
sample_ranges.pop(0)
sample_ranges

scores={}

for rn in sample_ranges:
    
    this_X = lc_data['X'][rn[0]:rn[1],:]
    this_y = lc_data['y'][rn[0]:rn[1]]
    
    this_scores, this_cms, this_labelandpred = mlutilities.kfold_report(n_folds,clf,this_X,this_y)
    
    scores[rn[1]]=this_scores
    
print scores.keys()

df_learning_curve = []
for k in scores.items():
    this_res = (k[0], k[1]['f1'][1],k[1]['f1'][0],k[1]['recall'][1],k[1]['precision'][1])
    df_learning_curve += [this_res]
df_learning_curve = pd.DataFrame(df_learning_curve,columns=['number_points','f1_true','f1_false','recall_true','precision_true'])    
df_learning_curve = df_learning_curve.sort('number_points')
df_learning_curve = df_learning_curve.set_index('number_points')
df_learning_curve.plot()
# Out:
# [11169.0, 6466.0, 1763.0, 8229.0, 3527.0, 9993.0, 5290.0, 587.0, 7054.0, 2351.0, 8817.0, 4114.0, 10581.0, 5878.0, 1175.0, 7641.0, 2939.0, 9405.0, 4702.0]

# %%
# df_learning_curve
0.8/11
# Out:
# 0.07272727272727274

# %%
#Adds labels and preds to data

reload(mlutilities)
from mlutilities import data_window

num_ahead = 0
num_behind = 0
lags = [ num_behind, num_ahead]

#df_window = data_window(labelandpred, df_all_march, lags)

#df_window = df_window[df_window['window']==True]
# print df_window['basedata'].value_counts()
# df_window = df_all_march.loc[labelandpred.index]


labelandpred.columns


# labelandpred2 = pd.merge(labelandpred,df_window, how='right', left_index=True, right_index=True,)

# labelandpred2.info()

df_output = df_all_march[['message','message_comments','page_url','comment_id']]
df_output = pd.merge(df_output,labelandpred,how='inner',left_index=True, right_index=True)
# df_output.info()
df_output['prediction'].value_counts()

# 
df_output.info()
# pd.crosstab(df_output.iteration, df_output.label)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11171 entries, 100163516839922_201 to 649587271733764_7731113
# Data columns (total 6 columns):
# message             11171 non-null object
# message_comments    11171 non-null object
# page_url            11171 non-null object
# comment_id          11171 non-null object
# labels              11171 non-null object
# prediction          11171 non-null object
# dtypes: object(6)

# %%
def lbl_correctness(row):
    
    if row['labels'] and row['prediction']:
        return 'TP'
    elif not(row['labels']) and not(row['prediction']):
        return 'TN'
    elif row['labels'] and not(row['prediction']):
        return 'FN'
    elif not(row['labels']) and row['prediction']:
        return 'FP'


df_output['label_correctness'] = df_output.apply(lbl_correctness, axis=1)
df_output['iteration'] = df_all_labels.iteration
# df_errortype = df_output[df_output['label_correctness']=='FP'][['page_url','message_comments','message','iteration']]

ct = pd.crosstab(df_output['labels'],df_output['iteration'],margins=True)

ct
print ct/ct.loc['All',:]*100
# print ct
# Out:
# iteration    0          1           2           3           4           5           6         All
# labels
# False        0   98.77551   89.196087   95.670996   98.178421   60.180542   82.658671   88.568615
# True       100    1.22449   10.803913    4.329004    1.821579   39.819458   17.341329   11.431385
# All        100  100.00000  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
# [3 rows x 8 columns]

# %%
import codecs
with codecs.open('../Data/UmatiLabels/Predictions/SixthIteration/predictions_trues_Allfeatures_comments.html','w',encoding='UTF-8') as fout:
        fout.write(df_output.to_html())

# %%
top_scores.argsort(0)
# Out:
# array([24999, 21958, 21957, ..., 47411, 39494, 28913])

# %%
#Top feature list
##Make sure you have run df_feature_index_mapping with correct features
support = fs.get_support(indices = True)
top_scores= fs.scores_[support]
support_sorted = support[top_scores.argsort(0)]
support_sorted

top_features = df_feature_index_mapping.loc[support_sorted]
top_features.columns = ['feature_label','feature_type']
top_features['word_count'] = top_features['feature_label'].apply( lambda x : len(x.split(' ')) )
# top_features[top_features['word_count']==1]

print top_features.head
# pd.DataFrame(support)
# Out:
# <bound method DataFrame.head of                feature_label      feature_type  word_count
# 83857                   ttaa  comments_message           1
# 73837                 sehemu  comments_message           1
# 80957                theives  comments_message           1
# 83858              ttaa owns  comments_message           2
# 36320              iwe mbaya  comments_message           2
# 55521               mungu na  comments_message           2
# 96408                   wool  comments_message           1
# 19271                  diary  comments_message           1
# 19272            diary power  comments_message           2
# 97725            ya wakikuyu  comments_message           2
# 84092                   tuko  comments_message           1
# 59254              ni kikuyu  comments_message           2
# 62228                  okuyu  comments_message           1
# 31710              hii kenya  comments_message           2
# ...

# %%
#Make table of features_labels, index_full, feature_type
#Create classifier with all training data, otherwise we use the last cross val trained
from sklearn.svm import SVC, LinearSVC
#X, y = shuffle(X, y, random_state=random_state)
half = int(X_red.shape[0] *0.9)
X_train, X_test = X_red[:half], X_red[half:]
y_train, y_test = y[:half], y[half:]


clf = SGDClassifier(alpha=0.0000001, n_iter=200, penalty='l1',n_jobs=4, loss='log')
probas_ = clf.fit(X_train,y_train).predict_proba(X_test)



# probas_ = classifier.fit(X_train, y_train).predict_proba(X_test)

# Compute ROC curve and area the curve
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, probas_[:, 1])
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)

# Plot ROC curve
plt.clf()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# Area under the ROC curve : 0.713496

# %%
f = np.vectorize(lambda x : max(0.0,min(x, 1.0)))

prbs = probas_[:,1] -0.01
prbs = f(prbs)



# Compute ROC curve and area the curve
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, prbs)
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)

# Plot ROC curve
plt.clf()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

pd.DataFrame(prbs)
# Out:
# Area under the ROC curve : 0.643230
#             0
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# 7    0.000000
# 8    0.000000
# 9    0.000000
# 10   0.000000
# 11   0.000000
# 12   0.000000
# 13   0.000000
# 14   0.000000
# 15   0.000000
# 16   0.000000
# 17   0.000000
# 18   0.990000
# 19   0.000000
# 20   0.000000
# 21   0.000000
# 22   0.000000
# 23   0.990000
# 24   0.000000
# 25   0.000000
# 26   0.000000
# 27   0.000000
# 28   0.000000
# 29   0.000000
# 30   0.000000
# 31   0.000000
# 32   0.000000
# 33   0.000000
# 34   0.000000
# 35   0.000000
# 36   0.000000
# 37   0.000000
# 38   0.000000
# 39   0.000000
# 40   0.000000
# 41   0.000000
# 42   0.000000
# 43   0.000000
# 44   0.000000
# 45   0.000000
# 46   0.423764
# 47   0.423764
# 48   0.423764
# 49   0.000000
# 50   0.423764
# 51   0.837881
# 52   0.423764
# 53   0.423764
# 54   0.423764
# 55   0.423764
# 56   0.423764
# 57   0.423764
# 58   0.423764
# ...

# %% [markdown]
# ### Predict on Full Data Set

# %%
#Create Features using vectorisers already fitted
comments_full = vectoriser_training.transform(df_all_march['message_comments'])
posts_full = vectoriser_posts.transform(df_all_march['message'])
pages_full = lb.transform(list(df_all_march['page_url'].values))
features_full_all = sp.hstack([comments_full,posts_full,pages_full])
print comments_full.shape
# print posts_full.shape
# print features_full_all.shape
# Out:
# (441940, 99384)

# %%
#Predict on Full
# fs.transform(features_full_all)
# comments_full_d=fs.transform(comments_full).todense()
# pred_full = clf_eval.predict(fs.transform(features_full_all))
pred_full = clf_eval.predict(fs.transform(comments_full))
# pred_full = clf_eval.predict(features_full_all)
#pd.DataFrame(pred_full).groupby(0).size()
# pred_trues_id = df_all_march[pred_full]
#pred_trues_id.shape

# %%
pd.Series(pred_full).value_counts()
# Out:
# False    434601
# True       7339
# dtype: int64

# %%
len(pred_full)#*0.148
# Out:
# 441940

# %%
df_all_march[pred_full == True][['message_comments']].head(50)
# Out:
#                                                                                                                                                                                                                                                     message_comments
# comment_id
# 347819751989096_1787359                                                                                                                                                                                       Ready to protect or ready to terroris SMG pls clarify?
# 335938819841073_1516475                                                                                                                                                                                                   Wajaluo ni kutuzi tu just like your raira.
# ...

# %% [markdown]
# ## Resample From Prediction and Send For Labelling

# %%
#Sample from predicted trues and falses
labels_preds = df_all_march[['page_url']] #Use this field for proportional sampling
labels_preds['label']=pred_full

#remove already labelled
# unlabelled_index = labels_preds.index - features.index
# label_preds = labels_preds.loc[unlabelled_index]

labels_preds_true = labels_preds[labels_preds['label']==True]
labels_preds_true
#Filter labels
trues = df_all_march.loc[labels_preds_true.index]

trues.shape
# Out:
# (7339, 33)

# %%
(trues.index - df_all_labels.index).shape
# Out:
# (10537,)

# %%
import random
sample_true = pd.Index(random.sample(trues.index,2000))
# sample_true = trues.index[0:2000]

# %%
from mlutilities import sample_proportions
#Do sample per group of labels
sample_true = sample_proportions(df_all_labels, trues, sample_size = 2000, proportion_weighted=0.1, block_size=1, top_N=5)
# Out:
# KTNKenya                             69
# NTVKenya                             34
# DailyNation                          33
# KenyansUnitedAgainstUhuruto2013      14
# K24TVNews                            12
# restofsample                       1838
# dtype: float64
# KTNKenya 2658
# NTVKenya 1125
# DailyNation 1064
# KenyansUnitedAgainstUhuruto2013 328
# K24TVNews 326
# restofsample
#  6723

# %%
import codecs
output_df = pd.DataFrame(df_all_march[['comment_id','page_url','message_comments','message']].loc[sample_true], copy=True)
# with codecs.open('../Data/UmatiLabels/Predictions/SixthIteration/predictions_trues_commentsfeatures.html','w',encoding='UTF-8') as fout:
#         fout.write(output_df.to_html())

# %%
df_all_march[['page_url', 'message','message_comments']].loc[sample_true].iloc[550:560]

# %%
output_df
# Out:
#                                             comment_id         page_url  \
# comment_id
# 100882613437831_1382              100882613437831_1382         KTNKenya
# 100968913426336_1593              100968913426336_1593         NTVKenya
# 101383403387352_1447              101383403387352_1447         NTVKenya
# 10151143135864058_24349814  10151143135864058_24349814         NTVKenya
# 10151144891459058_24362472  10151144891459058_24362472         NTVKenya
# 10151145952254058_24367591  10151145952254058_24367591         NTVKenya
# 10151146253204058_24369923  10151146253204058_24369923         NTVKenya
# 10151146253204058_24370109  10151146253204058_24370109         NTVKenya
# 10151150159099058_24378155  10151150159099058_24378155         NTVKenya
# 10151150839704058_24384261  10151150839704058_24384261         NTVKenya
# 10151151553569058_7201857    10151151553569058_7201857         NTVKenya
# 10151151779949058_24390851  10151151779949058_24390851         NTVKenya
# ...

# %%
#Function for doing proportional sampling
#Very slow, must be able to optimise

from math import floor
import random

def sample_proportions(labels,
                        data,
                        sample_size, 
                        proportion_weighted, 
                        block_size = 10,
                        top_N = 10):
    #Function for doing proportional sampling
    #Very slow, must be able to optimise
    
    
    """
    Samples in proportion to pages already labelled - Need to be able to specify filter on label
    Inputs:
    
    labels - indexes of already labelled data and label
    data - data that needs to be labelled
    sample_size - size of final sample (approximate)
    proportion_weighted - proportion of sample to correspond to page proportion weighting scheme
    block_size - size of continuous comments blocks to label
    top_N - How many pages to use in the proportional weighing scheme

    Output:
    Index of samples as a subset of the original data index
    """
    
    
    #Construct df with pages and number of samples per page with respect to proportion
    freq_pages  = data.page_url.loc[labels.index].value_counts()
    #freq_pages  = data.loc[labels.index].page_url.value_counts()
    pc_pages = freq_pages/freq_pages.sum()
    buckets = (pc_pages.iloc[0:top_N]*sample_size*proportion_weighted).apply(floor)
    #Append the non-proportional number of samples to take
    buckets= buckets.append(pd.Series( sample_size - buckets.sum(), index=['restofsample']))
    print buckets
    #Get index set of samples minus indexes of already labelled samples
    index_no_labels = data.index - labels.index
    
    #Get groups and index to make samples from and filter out already labelled
    df_groups = data[['page_url']].loc[index_no_labels]
    
    #Create empty of index of final samples
    sample_index = pd.Index([])
    
    
    #Do sampling
    for (group_lb, group_num_samples) in buckets.iteritems():
        
        if group_lb != 'restofsample':
            #get group index
            df_thisgroup = df_groups[df_groups['page_url'] == group_lb]
        
        elif group_lb == 'restofsample':
            #This will break unless rest_of_sample label is last
            rest_of_sample_index = index_no_labels - sample_index
            df_thisgroup = df_groups.loc[rest_of_sample_index]
            
        group_size = df_thisgroup.shape[0]
        print group_lb, group_size
        
        #We want to sample continuous blocks size N from group
        samples = set()
        sample_set = set([i for i in range(0,group_size-block_size)])
        
        while(len(samples) < group_num_samples):
            start_block = random.choice(list(sample_set))
            block = set(range(start_block,start_block+block_size))
            
            samples = samples.union(block) #Add lastest indexes sampled
            sample_set = sample_set.difference(block) #Remove indexes from set to be sampled
        
        #Get index labels
        samples = list(samples)
        samples.sort() #note that this working inplace
        this_index = [df_thisgroup.index[it] for it in samples] #Get index from full set rather than group
        this_index = pd.Index(this_index)
        
        sample_index += this_index
        
    return sample_index

# %%
#Send for labelling

# %%
#Import labels

# %%
#Repeat training
