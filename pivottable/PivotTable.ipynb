# %%
import pandas as pd
from IPython.html import widgets
from IPython.html.widgets import interact, interactive# Widget definitions
from IPython.display import display # Used to display widgets in the notebook

# %%
[widget for widget in dir(widgets) if widget.endswith('Widget')]
# Out:
# ['AccordionWidget',
#  'BoundedFloatTextWidget',
#  'BoundedIntTextWidget',
#  'ButtonWidget',
#  'CheckboxWidget',
#  'ContainerWidget',
#  'DOMWidget',
#  'DropdownWidget',
#  'FloatProgressWidget',
#  'FloatSliderWidget',
#  'FloatTextWidget',
#  'HTMLWidget',
#  'ImageWidget',
#  'IntProgressWidget',
#  'IntSliderWidget',
#  'IntTextWidget',
#  'LatexWidget',
#  'PopupWidget',
#  'RadioButtonsWidget',
#  'SelectWidget',
#  'TabWidget',
#  'TextWidget',
#  'TextareaWidget',
#  'ToggleButtonWidget',
#  'ToggleButtonsWidget',
#  'Widget']

# %%
tabwid = widgets.TabWidget()
tabwid.keys
# Out:
# ['_view_name',
#  '_titles',
#  'msg_throttle',
#  '_children',
#  'selected_index',
#  '_css',
#  'visible']

# %%
data = pd.read_csv('./TestCO2.csv')
data
# Out:
#    Plant         Type   Treatment  conc  uptake
# 0    Qn1       Quebec  nonchilled    95    16.0
# 1    Qn1       Quebec  nonchilled   175    30.4
# 2    Qn1       Quebec  nonchilled   250    34.8
# 3    Qn1       Quebec  nonchilled   350    37.2
# 4    Qn1       Quebec  nonchilled   500    35.3
# 5    Qn1       Quebec  nonchilled   675    39.2
# 6    Qn1       Quebec  nonchilled  1000    39.7
# 7    Qn2       Quebec  nonchilled    95    13.6
# 8    Qn2       Quebec  nonchilled   175    27.3
# 9    Qn2       Quebec  nonchilled   250    37.1
# 10   Qn2       Quebec  nonchilled   350    41.8
# 11   Qn2       Quebec  nonchilled   500    40.6
# 12   Qn2       Quebec  nonchilled   675    41.4
# 13   Qn2       Quebec  nonchilled  1000    44.3
# 14   Qn3       Quebec  nonchilled    95    16.2
# 15   Qn3       Quebec  nonchilled   175    32.4
# 16   Qn3       Quebec  nonchilled   250    40.3
# 17   Qn3       Quebec  nonchilled   350    42.1
# 18   Qn3       Quebec  nonchilled   500    42.9
# ...

# %%
#Get possible fields
fields = list(data.columns.values)
unused_fields = list(fields)

rows = []
columns = []
data = []

#Field widget vars
selected_field = None
selected_row = None
selected_col = None

print "rows ", rows 
print "columns ", columns
print "data ", data
# Out:
# rows  []
# columns  []
# data  []

# %%
widgetFieldList = widgets.SelectWidget(values=fields, description= 'Fields')
widgetRowList = widget.SelectWidget(values = rows, description = 'Rows')
widgetColList = widget.SelectWidget(values = cols, description = 'Cols')
widgetDataList = widget.SelectWidget(values = data, description = 'Data')

# widgetAddRowButton 
widgetAddRow = widget.
# widgetAddColumnButton
# widgetAddDataButton
# widgetDelRowButton
# widgetDelColButton
# widgetDelDataButton

# Make PT button

def widgetHandler(Fields):
    print selected_field = Field
    print "rows ", rows 
    print "columns ", columns
    print "data ", data



container
# i = interact(widgetHandler, Fields = widgetFieldList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-a9750b3a4927> in widgetHandler(Fields)
#      10
#      11 def widgetHandler(Fields):
# ---> 12     print sele
#      13     print "rows ", rows
#      14     print "columns ", columns
#
# NameError: global name 'sele' is not defined

# %%
i.widget
